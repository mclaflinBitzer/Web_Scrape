# %%
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd
from datetime import datetime

# %% [markdown]
# ### Successful approach

# %%
def base_fetch_method(url):
    headers = {
        "User-Agent": (
            "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
            "AppleWebKit/537.36 (KHTML, like Gecko) "
            "Chrome/123.0.0.0 Safari/537.36"
        )
    }
    response = requests.get(url, headers=headers, verify=False, timeout=30)
    print(response.status_code)
    html_doc = response.text
    soup = BeautifulSoup(html_doc, 'html.parser')
    return soup

# %% [markdown]
# ### Selenium approach

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service

options = Options()
options.add_argument("--headless")   # optional

driver = webdriver.Chrome(options=options)   # <-- No need to download driver manually!
driver.get(url)

print(driver.page_source)
with open("test.txt", "w") as f:
    f.write(driver.page_source)
driver.quit()

# %% [markdown]
# ### Selenium approach 2

# %% [markdown]
# import os
# from selenium import webdriver
# from selenium.webdriver.chrome.service import Service
# from selenium.webdriver.chrome.options import Options
# from webdriver_manager.chrome import ChromeDriverManager
#
# # Disable SSL verification for webdriver_manager
# os.environ["WDM_SSL_VERIFY"] = "0"
#
# # ----------------------------
# # Chrome Options
# # ----------------------------
# chrome_options = Options()
# chrome_options.add_argument("--headless=new")
# chrome_options.add_argument("--disable-gpu")
# chrome_options.add_argument("--no-sandbox")
# chrome_options.add_argument("--disable-dev-shm-usage")
# chrome_options.add_argument("--ignore-certificate-errors")
# chrome_options.add_argument(
#     "user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
#     "AppleWebKit/537.36 (KHTML, like Gecko) "
#     "Chrome/120.0.0.0 Safari/537.36"
# )
#
# # ----------------------------
# # Start WebDriver
# # ----------------------------
# driver_path = ChromeDriverManager().install()
# driver = webdriver.Chrome(service=Service(driver_path), options=chrome_options)
#
# # ----------------------------
# # Load Page
# # ----------------------------
# driver.get("https://naturalrefrigerants.com/news/")
#
# # ----------------------------
# # Get HTML
# # ----------------------------
# html = driver.page_source
# print(html[:2000])  # preview first 2000 characters
#
# # ----------------------------
# # Quit driver
# # ----------------------------
# driver.quit()
