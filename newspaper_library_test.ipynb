# %%
pip install newspaper3k
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#      ---------------------------------------- 0.0/7.4 MB ? eta -:--:--
#      --------------- ------------------------ 2.9/7.4 MB 18.6 MB/s eta 0:00:01
#      ---------------------------------------  7.3/7.4 MB 19.7 MB/s eta 0:00:01
#      ---------------------------------------- 7.4/7.4 MB 19.1 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...

# %%
pip install lxml[html_clean]
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from newspaper import Article
import ssl

# Ignore SSL certificate verification (for testing)
ssl._create_default_https_context = ssl._create_unverified_context

url = "https://www.3blmedia.com/news/trane-technologies-provides-15-million-grant-science-museum-minnesota-empower-youth-through"

article = Article(url)
article.download()
article.parse()

print(article.title)
print(article.publish_date)
print(article.text[:500])
# Out:
# ---------------------------------------------------------------------------
# ArticleException                          Traceback (most recent call last)
# Cell In[6], line 11
#       9 article = Article(url)
#      10 article.download()
# ---> 11 article.parse()
#      13 print(article.title)
#      14 print(article.publish_date)
#
# File c:\Users\203156\Desktop\Pipelines\Webscraping\venv\Lib\site-packages\newspaper\article.py:191, in Article.parse(self)
#     190 def parse(self):
# --> 191     self.throw_if_not_downloaded_verbose()
#     193     self.doc = self.config.get_parser().fromstring(self.html)
#     194     self.clean_doc = copy.deepcopy(self.doc)
#
# File c:\Users\203156\Desktop\Pipelines\Webscraping\venv\Lib\site-packages\newspaper\article.py:531, in Article.throw_if_not_downloaded_verbose(self)
#     529     raise ArticleException('You must `download()` an article first!')
#     530 elif self.download_state == ArticleDownloadState.FAILED_RESPONSE:
# ...
