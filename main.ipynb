# %%
import pandas as pd
from Scripts.nr_scrape import nr_fetch_method, nr_url_extraction, nr_article_scraping_method
from Scripts.trane_scrape import trane_fetch_method, trane_url_extraction, trane_scrape_article
from Scripts.API_push import api_push

# %% [markdown]
# #### base urls

# %%
## Base URLs
nr_url = 'https://naturalrefrigerants.com/news/'
trane_url = 'https://www.tranetechnologies.com/en/index/news.html'

# %% [markdown]
# #### dataframe creation

# %%
## dataframe defining
## columns: title, summary, publication_date->dateline, article_body->newslinetext, attachmenturl
compiled_article_data = pd.DataFrame(columns=['title', 'summary', 'dateline', 'newslinetext', 'attachmenturl','source'])

# %% [markdown]
# #### Natural Refrigerants Scrape Process

# %%
nr_soup = nr_fetch_method(nr_url)
nr_article_links = nr_url_extraction(nr_soup)
for link in nr_article_links:
    compiled_article_data = pd.concat([compiled_article_data, nr_article_scraping_method(link)])
# Out:
# c:\Users\203156\Desktop\Pipelines\Webscraping\venv\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'naturalrefrigerants.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# 200
# ['https://naturalrefrigerants.com/news/eu-launches-e1-8-million-heat-pump-subscription-model-for-leased-commercial-and-public-buildings/', 'https://naturalrefrigerants.com/news/eu-launches-e1-8-million-heat-pump-subscription-model-for-leased-commercial-and-public-buildings/', 'https://naturalrefrigerants.com/news/frascolds-new-nexus-screw-compressor-for-high-temperature-heat-pump-applications-can-work-with-butane-and-isopentane/', 'https://naturalrefrigerants.com/news/frascolds-new-nexus-screw-compressor-for-high-temperature-heat-pump-applications-can-work-with-butane-and-isopentane/', 'https://naturalrefrigerants.com/news/epta-completes-its-acquisition-of-hauser/', 'https://naturalrefrigerants.com/news/epta-completes-its-acquisition-of-hauser/', 'https://naturalrefrigerants.com/news/hyting-commissions-worlds-first-customer-installed-catalytic-hydrogen-air-heating-system/', 'https://naturalrefrigerants.com/news/hyting-commissions-worlds-first-customer-installed-catalytic-hydrogen-air-heating-system/', 'https://naturalrefrigerants.com/news/part-2-bacs-heat-rejection-and-single-phase-immersion-technology-provide-end-to-end-cooling-solution-for-data-centers/', 'https://naturalrefrigerants.com/news/part-2-bacs-heat-rejection-and-single-phase-immersion-technology-provide-end-to-end-cooling-solution-for-data-centers/', 'https://naturalrefrigerants.com/news/trade-groups-appeal-new-york-court-decision-rejecting-effort-to-stop-hfc-regs/', 'https://naturalrefrigerants.com/news/trade-groups-appeal-new-york-court-decision-rejecting-effort-to-stop-hfc-regs/', 'https://naturalrefrigerants.com/news/california-grant-of-1-5-million-to-fund-research-on-risk-of-propane-in-outdoor-heat-pumps/', 'https://naturalrefrigerants.com/news/california-grant-of-1-5-million-to-fund-research-on-risk-of-propane-in-outdoor-heat-pumps/', 'https://naturalrefrigerants.com/news/bock-co2-compressors-found-to-vibrate-less-at-ohio-supermarket/', 'https://naturalrefrigerants.com/news/b
com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# 200
# c:\Users\203156\Desktop\Pipelines\Webscraping\Scripts\nr_scrape.py:90: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   new_data = pd.concat([new_data, pd.DataFrame([new_row])], ignore_index=True)
# c:\Users\203156\Desktop\Pipelines\Webscraping\venv\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'naturalrefrigerants.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# 200
# c:\Users\203156\Desktop\Pipelines\Webscraping\Scripts\nr_scrape.py:90: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   new_data = pd.concat([new_data, pd.DataFrame([new_row])], ignore_index=True)

# %% [markdown]
# #### Trane Technologies Scrape Process

# %%
trane_soup = trane_fetch_method(trane_url)

trane_article_links = trane_url_extraction(trane_soup)

for link in trane_article_links:
    compiled_article_data = pd.concat([compiled_article_data, trane_scrape_article(link)], ignore_index=True)
# Out:
# c:\Users\203156\Desktop\Pipelines\Webscraping\venv\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.tranetechnologies.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# 200
# https://investors.tranetechnologies.com/news-and-events/news-releases/news-release-details/2026/Trane-Technologies-Completes-Acquisition-of-Stellar-Energy/default.aspx
# c:\Users\203156\Desktop\Pipelines\Webscraping\venv\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'investors.tranetechnologies.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# 200
# https://investors.tranetechnologies.com/news-and-events/news-releases/news-release-details/2026/Trane-Technologies-to-Acquire-LiquidStack-to-Accelerate-EndtoEnd-Data-Center-Thermal-Management-Solutions/default.aspx
# c:\Users\203156\Desktop\Pipelines\Webscraping\Scripts\trane_scrape.py:101: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   new_data = pd.concat([new_data, pd.DataFrame([new_row])], ignore_index=True)
# c:\Users\203156\Desktop\Pipelines\Webscraping\venv\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'investors.tranetechnologies.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# 200
# https://www.3blmedia.com/news/reuben-trane-named-2026-class-national-inventors-hall-fame
# c:\Users\203156\Desktop\Pipelines\Webscraping\Scripts\trane_scrape.py:101: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   new_data = pd.concat([new_data, pd.DataFrame([new_row])], ignore_index=True)
# c:\Users\203156\Desktop\Pipelines\Webscraping\venv\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.3blmedia.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# 200
# https://investors.tranetechnologies.com/news-and-events/news-releases/news-release-details/2026/Trane-Technologies-to-Present-at-the-Barclays-Industrial-Select-Conference/default.aspx
# c:\Users\203156\Desktop\Pipelines\Webscraping\Scripts\trane_scrape.py:101: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   new_data = pd.concat([new_data, pd.DataFrame([new_row])], ignore_index=True)
# c:\Users\203156\Desktop\Pipelines\Webscraping\venv\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'investors.tranetechnologies.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# 200
# https://investors.tranetechnologies.com/news-and-events/news-releases/news-release-details/2026/Trane-Technologies-to-Present-at-the-Citi-Global-Industrial-Tech-and-Mobility-Conference/default.aspx
# c:\Users\203156\Desktop\Pipelines\Webscraping\Scripts\trane_scrape.py:101: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   new_data = pd.concat([new_data, pd.DataFrame([new_row])], ignore_index=True)
# c:\Users\203156\Desktop\Pipelines\Webscraping\venv\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'investors.tranetechnologies.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# 200
# https://investors.tranetechnologies.com/news-and-events/news-releases/news-release-details/2026/Trane-Technologies-Increases-Dividend-by-12-Declares-Quarterly-Dividend/default.aspx
# c:\Users\203156\Desktop\Pipelines\Webscraping\Scripts\trane_scrape.py:101: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   new_data = pd.concat([new_data, pd.DataFrame([new_row])], ignore_index=True)
# c:\Users\203156\Desktop\Pipelines\Webscraping\venv\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'investors.tranetechnologies.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# 200
# c:\Users\203156\Desktop\Pipelines\Webscraping\Scripts\trane_scrape.py:101: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   new_data = pd.concat([new_data, pd.DataFrame([new_row])], ignore_index=True)

# %% [markdown]
# ### Writing to Excel File

# %%
compiled_article_data.to_excel('Data/compiled_article_data.xlsx', index=False)

# %% [markdown]
# ### Pushing the data to Comintelli API

# %%
api_push()
# Out:
# c:\Users\203156\Desktop\Pipelines\Webscraping\venv\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'my.intelligence2day.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# <Response [200]>
# b'{"MESSAGE":"","ARTICLEID":"47843796"}'
# c:\Users\203156\Desktop\Pipelines\Webscraping\venv\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'my.intelligence2day.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# <Response [200]>
# b'{"MESSAGE":"","ARTICLEID":"47843797"}'
# c:\Users\203156\Desktop\Pipelines\Webscraping\venv\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'my.intelligence2day.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# <Response [200]>
# b'{"MESSAGE":"","ARTICLEID":"47843798"}'
# c:\Users\203156\Desktop\Pipelines\Webscraping\venv\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'my.intelligence2day.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# <Response [200]>
# b'{"MESSAGE":"","ARTICLEID":"47843799"}'
# c:\Users\203156\Desktop\Pipelines\Webscraping\venv\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'my.intelligence2day.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# <Response [200]>
# b'{"MESSAGE":"","ARTICLEID":"47843800"}'
# c:\Users\203156\Desktop\Pipelines\Webscraping\venv\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'my.intelligence2day.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# <Response [200]>
# b'{"MESSAGE":"","ARTICLEID":"47843801"}'
# c:\Users\203156\Desktop\Pipelines\Webscraping\venv\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'my.intelligence2day.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# <Response [200]>
# b'{"MESSAGE":"","DUPLICATE":"Duplicate found","ARTICLEID":"0EEE559382A493C54C7876717A7CEE48"}'
# c:\Users\203156\Desktop\Pipelines\Webscraping\venv\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'my.intelligence2day.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# <Response [200]>
# b'{"MESSAGE":"","ARTICLEID":"47843802"}'
# c:\Users\203156\Desktop\Pipelines\Webscraping\venv\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'my.intelligence2day.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# <Response [200]>
# b'{"MESSAGE":"","ARTICLEID":"47843803"}'
# c:\Users\203156\Desktop\Pipelines\Webscraping\venv\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'my.intelligence2day.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# <Response [200]>
# b'{"MESSAGE":"","DUPLICATE":"Duplicate found","ARTICLEID":"EC02AE098819AECEB5DFEB826CAFB75C"}'
# c:\Users\203156\Desktop\Pipelines\Webscraping\venv\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'my.intelligence2day.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# <Response [200]>
# b'{"MESSAGE":"","ARTICLEID":"47843804"}'
# c:\Users\203156\Desktop\Pipelines\Webscraping\venv\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'my.intelligence2day.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# <Response [200]>
# b'{"MESSAGE":"","DUPLICATE":"Duplicate found","ARTICLEID":"A578D6978A9BC9E4A6F0AF00B1E5C617"}'
# c:\Users\203156\Desktop\Pipelines\Webscraping\venv\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'my.intelligence2day.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# <Response [200]>
# b'{"MESSAGE":"","ARTICLEID":"47843805"}'
# c:\Users\203156\Desktop\Pipelines\Webscraping\venv\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'my.intelligence2day.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# <Response [200]>
# b'{"MESSAGE":"","ARTICLEID":"47843806"}'
# c:\Users\203156\Desktop\Pipelines\Webscraping\venv\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'my.intelligence2day.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# <Response [200]>
# b'{"MESSAGE":"","ARTICLEID":"47843807"}'
# c:\Users\203156\Desktop\Pipelines\Webscraping\venv\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'my.intelligence2day.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# <Response [200]>
# b'{"MESSAGE":"","ARTICLEID":"47843808"}'
# c:\Users\203156\Desktop\Pipelines\Webscraping\venv\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'my.intelligence2day.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# <Response [200]>
# b'{"MESSAGE":"","ARTICLEID":"47843810"}'
# c:\Users\203156\Desktop\Pipelines\Webscraping\venv\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'my.intelligence2day.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# <Response [200]>
# b'{"MESSAGE":"","ARTICLEID":"47843811"}'
# c:\Users\203156\Desktop\Pipelines\Webscraping\venv\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'my.intelligence2day.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# <Response [200]>
# b'{"MESSAGE":"","ARTICLEID":"47843812"}'
# c:\Users\203156\Desktop\Pipelines\Webscraping\venv\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'my.intelligence2day.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# <Response [200]>
# b'{"MESSAGE":"","DUPLICATE":"Duplicate found","ARTICLEID":"653263B5EF5C66B76DBD18EC890F7B8C"}'
# c:\Users\203156\Desktop\Pipelines\Webscraping\venv\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'my.intelligence2day.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\203156\Desktop\Pipelines\Webscraping\venv\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'my.intelligence2day.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# <Response [200]>
# b'{"MESSAGE":"","DUPLICATE":"Duplicate found","ARTICLEID":"4A07DB3255D26AD9D8F4A6F868A23B5C"}'
# <Response [200]>
# b'{"MESSAGE":"","DUPLICATE":"Duplicate found","ARTICLEID":"2C435ABF57982228DCA5624D80FE06DC"}'
