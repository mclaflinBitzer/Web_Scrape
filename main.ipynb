# %%
import pandas as pd
import os
import logging
import urllib3
from Scripts.nr_scrape import nr_fetch_method, nr_url_extraction, nr_article_scraping_method
from Scripts.trane_scrape import trane_fetch_method, trane_url_extraction, trane_scrape_article
from Scripts.API_push import api_push
from Scripts.logger import setup_logger
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

# %%
logger = setup_logger('web_scraping_pipeline')

# %% [markdown]
# #### base urls

# %%
## Base URLs
nr_url = os.getenv('nr_base_url')
trane_url = os.getenv('trane_base_url')

# %% [markdown]
# #### List creation
# enables appending dicts of article data to this list instead of df concat/creation

# %%
all_articles = []

# %% [markdown]
# #### Natural Refrigerants Scrape Process

# %%
logger.info("fetching html from base nr_url")
nr_soup = nr_fetch_method(nr_url)

logger.info("extracting article links from nr_soup")
nr_article_links = nr_url_extraction(nr_soup)
for link in nr_article_links:
    logger.info(f"scraping article from link: {link}")
    all_articles.append(nr_article_scraping_method(link))
# Out:
# ['https://naturalrefrigerants.com/news/copelands-medium-temp-scroll-compressor-seen-as-expanding-co2-market-in-north-america/', 'https://naturalrefrigerants.com/news/copelands-medium-temp-scroll-compressor-seen-as-expanding-co2-market-in-north-america/', 'https://naturalrefrigerants.com/news/minnesota-flow-environmental-services-st-paul-local-455-team-up-for-co2-heat-pump-training-and-demonstrations/', 'https://naturalrefrigerants.com/news/minnesota-flow-environmental-services-st-paul-local-455-team-up-for-co2-heat-pump-training-and-demonstrations/', 'https://naturalrefrigerants.com/news/eu-launches-e1-8-million-heat-pump-subscription-model-for-leased-commercial-and-public-buildings/', 'https://naturalrefrigerants.com/news/eu-launches-e1-8-million-heat-pump-subscription-model-for-leased-commercial-and-public-buildings/', 'https://naturalrefrigerants.com/news/frascolds-new-nexus-screw-compressor-for-high-temperature-heat-pump-applications-can-work-with-butane-and-isopentane/', 'https://naturalrefrigerants.com/news/frascolds-new-nexus-screw-compressor-for-high-temperature-heat-pump-applications-can-work-with-butane-and-isopentane/', 'https://naturalrefrigerants.com/news/epta-completes-its-acquisition-of-hauser/', 'https://naturalrefrigerants.com/news/epta-completes-its-acquisition-of-hauser/', 'https://naturalrefrigerants.com/news/hyting-commissions-worlds-first-customer-installed-catalytic-hydrogen-air-heating-system/', 'https://naturalrefrigerants.com/news/hyting-commissions-worlds-first-customer-installed-catalytic-hydrogen-air-heating-system/', 'https://naturalrefrigerants.com/news/part-2-bacs-heat-rejection-and-single-phase-immersion-technology-provide-end-to-end-cooling-solution-for-data-centers/', 'https://naturalrefrigerants.com/news/part-2-bacs-heat-rejection-and-single-phase-immersion-technology-provide-end-to-end-cooling-solution-for-data-centers/', 'https://naturalrefrigerants.com/news/trade-groups-appeal-new-york-court-decision-rejecting-effort-to-stop-hfc-regs/', 'https://naturalrefrigerants.com/news/trade-groups-appeal-new-york-court-decision-rejecting-effort-to-stop-hfc-regs/', 'https://naturalrefrigerants.com/news/california-grant-of-1-5-million-to-fund-research-on-risk-of-propane-in-outdoor-heat-pumps/', 'https://naturalrefrigerants.com/news/california-grant-of-1-5-million-to-fund-research-on-risk-of-propane-in-outdoor-heat-pumps/', 'https://naturalrefrigerants.com/news/bock-co2-compressors-found-to-vibrate-less-at-ohio-supermarket/', 'https://naturalrefrigerants.com/news/bock-co2-compressors-found-to-vibrate-less-at-ohio-supermarket/', 'https://naturalrefrigerants.com/news/advansor-launches-enhanced-cubig-ii-with-50-more-cooling-and-heating-capacity/', 'https://naturalrefrigerants.com/news/advansor-launches-enhanced-cubig-ii-with-50-more-cooling-and-heating-capacity/', 'https://naturalrefrigerants.com/news/johnson-controls-introduces-air-to-water-reversible-york-yas-r290-heat-pump-models-to-the-european-market/', 'https://naturalrefrigerants.com/news/johnson-controls-introduces-air-to-water-reversible-york-yas-r290-heat-pump-models-to-the-european-market/', 'https://naturalrefrigerants.com/news/part-1-bacs-heat-rejection-and-single-phase-immersion-technology-provide-end-to-end-cooling-solution-for-data-centers/', 'https://naturalrefrigerants.com/news/part-1-bacs-heat-rejection-and-single-phase-immersion-technology-provide-end-to-end-cooling-solution-for-data-centers/', 'https://naturalrefrigerants.com/news/hvacr-japan-2026-jexsys-launches-130c-high-temperature-hot-water-co2-heat-pump/', 'https://naturalrefrigerants.com/news/hvacr-japan-2026-jexsys-launches-130c-high-temperature-hot-water-co2-heat-pump/', 'https://naturalrefrigerants.com/news/guide-to-working-with-propane-available-in-english/', 'https://naturalrefrigerants.com/news/guide-to-working-with-propane-available-in-english/', 'https://naturalrefrigerants.com/news/cencosud-nestle-and-oxxo-colombia-to-present-at-atmo-latam-2026/', 'https://naturalrefrig ...

# %% [markdown]
# #### Trane Technologies Scrape Process

# %%
logger.info("fetching html from base trane_url")
trane_soup = trane_fetch_method(trane_url)

logger.info("extracting article links from trane_soup")
trane_article_links = trane_url_extraction(trane_soup)

for link in trane_article_links:
    logger.info(f"scraping article from link: {link}")
    all_articles.append(trane_scrape_article(link))
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File c:\Users\203156\Desktop\Pipelines\Webscraping\venv\Lib\site-packages\urllib3\util\connection.py:73, in create_connection(address, timeout, source_address, socket_options)
#      72     sock.bind(source_address)
# ---> 73 sock.connect(sa)
#      74 # Break explicitly a reference cycle
#
# TimeoutError: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 6
#       3 trane_article_links = trane_url_extraction(trane_soup)
#       5 for link in trane_article_links:
# ----> 6     all_articles.append(trane_scrape_article(link))
#
# File c:\Users\203156\Desktop\Pipelines\Webscraping\Scripts\trane_scrape.py:62, in trane_scrape_article(url)
#      60 def trane_scrape_article(url):
# ---> 62     soup = trane_fetch_method(url)
#      64     ## extract title
#      65     title=soup.find('h3').get_text().strip()
#
# File c:\Users\203156\Desktop\Pipelines\Webscraping\Scripts\trane_scrape.py:33, in trane_fetch_method(url)
#      25 headers = {
#      26     "User-Agent": (
#      27         "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
#    (...)     30     )
#      31 }
#      32 try:
# ---> 33     response = requests.get(url, headers=headers, verify=False, timeout=30)
#      34     html_doc = response.text
#      35     soup = BeautifulSoup(html_doc, 'html.parser')
#
# File c:\Users\203156\Desktop\Pipelines\Webscraping\venv\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)     70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File c:\Users\203156\Desktop\Pipelines\Webscraping\venv\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\203156\Desktop\Pipelines\Webscraping\venv\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\203156\Desktop\Pipelines\Webscraping\venv\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\203156\Desktop\Pipelines\Webscraping\venv\Lib\site-packages\requests\adapters.py:644, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     641     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     643 try:
# --> 644     resp = conn.urlopen(
#     645         method=request.method,
#     646         url=url,
#     647         body=request.body,
#     648         headers=request.headers,
#     649         redirect=False,
#     650         assert_same_host=False,
#     651         preload_content=False,
#     652         decode_content=False,
#     653         retries=self.max_retries,
#     654         timeout=timeout,
#     655         chunked=chunked,
#     656     )
#     658 except (ProtocolError, OSError) as err:
#     659     raise ConnectionError(err, request=request)
#
# File c:\Users\203156\Desktop\Pipelines\Webscraping\venv\Lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File c:\Users\203156\Desktop\Pipelines\Webscraping\venv\Lib\site-packages\urllib3\connectionpool.py:464, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     461 try:
#     462     # Trigger any extra validation we need to do.
#     463     try:
# --> 464         self._validate_conn(conn)
#     465     except (SocketTimeout, BaseSSLError) as e:
#     466         self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File c:\Users\203156\Desktop\Pipelines\Webscraping\venv\Lib\site-packages\urllib3\connectionpool.py:1093, in HTTPSConnectionPool._validate_conn(self, conn)
#    1091 # Force connect early to allow us to validate the connection.
#    1092 if conn.is_closed:
# -> 1093     conn.connect()
#    1095 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#    1096 if not conn.is_verified and not conn.proxy_is_verified:
#
# File c:\Users\203156\Desktop\Pipelines\Webscraping\venv\Lib\site-packages\urllib3\connection.py:759, in HTTPSConnection.connect(self)
#     757 try:
#     758     sock: socket.socket | ssl.SSLSocket
# --> 759     self.sock = sock = self._new_conn()
#     760     server_hostname: str = self.host
#     761     tls_in_tls = False
#
# File c:\Users\203156\Desktop\Pipelines\Webscraping\venv\Lib\site-packages\urllib3\connection.py:204, in HTTPConnection._new_conn(self)
#     199 """Establish a socket connection and set nodelay settings on it.
#     200
#     201 :return: New socket connection.
#     202 """
#     203 try:
# --> 204     sock = connection.create_connection(
#     205         (self._dns_host, self.port),
#     206         self.timeout,
#     207         source_address=self.source_address,
#     208         socket_options=self.socket_options,
#     209     )
#     210 except socket.gaierror as e:
#     211     raise NameResolutionError(self.host, self, e) from e
#
# File c:\Users\203156\Desktop\Pipelines\Webscraping\venv\Lib\site-packages\urllib3\util\connection.py:81, in create_connection(address, timeout, source_address, socket_options)
#      79         err = _
#      80         if sock is not None:
# ---> 81             sock.close()
#      83 if err is not None:
#      84     try:
#
# File C:\Program Files\Python312\Lib\socket.py:501, in socket.close(self)
#     497 def _real_close(self, _ss=_socket.socket):
#     498     # This function should not reference any globals. See issue #808164.
#     499     _ss.close(self)
# --> 501 def close(self):
#     502     # This function should not reference any globals. See issue #808164.
#     503     self._closed = True
#     504     if self._io_refs <= 0:
#
# KeyboardInterrupt:

# %% [markdown]
# ### Writing to Excel File

# %%
logger.info("Writing compiled article data to Excel file")
compiled_article_data = pd.DataFrame(all_articles)
compiled_article_data.to_excel('Data/compiled_article_data.xlsx', index=False)

# %% [markdown]
# ### Pushing the data to Comintelli API

# %%
logger.info("Pushing compiled article data to API")
api_push()
# Out:
# 2026-02-24 17:19:53,139 | INFO | web_scraping_logger | Fetching api credentials and keys from .env file
# 2026-02-24 17:19:53,139 | INFO | web_scraping_logger | Fetching api credentials and keys from .env file
# 2026-02-24 17:19:53,142 | INFO | web_scraping_logger | Reading compiled article data from excel file
# 2026-02-24 17:19:53,142 | INFO | web_scraping_logger | Reading compiled article data from excel file
# c:\Users\203156\Desktop\Pipelines\Webscraping\venv\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'my.intelligence2day.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# 2026-02-24 17:19:53,462 | INFO | web_scraping_logger | API response status code for article 'Copeland’s Medium-Temp Scroll Compressor Seen as Expanding CO2 Market in North America': 200 and the content b'{"MESSAGE":"","DUPLICATE":"Duplicate found","ARTICLEID":"ADD7F8D7ECE93B9CDB8FA35401A0E98B"}'
# 2026-02-24 17:19:53,462 | INFO | web_scraping_logger | API response status code for article 'Copeland’s Medium-Temp Scroll Compressor Seen as Expanding CO2 Market in North America': 200 and the content b'{"MESSAGE":"","DUPLICATE":"Duplicate found","ARTICLEID":"ADD7F8D7ECE93B9CDB8FA35401A0E98B"}'
# c:\Users\203156\Desktop\Pipelines\Webscraping\venv\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'my.intelligence2day.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# 2026-02-24 17:19:53,709 | INFO | web_scraping_logger | API response status code for article 'Trade Groups Appeal New York Court Decision Rejecting Effort to Stop HFC Regs': 200 and the content b'{"MESSAGE":"","DUPLICATE":"Duplicate found","ARTICLEID":"6C39F4850C047B7B3F65A10C8664E225"}'
# 2026-02-24 17:19:53,709 | INFO | web_scraping_logger | API response status code for article 'Trade Groups Appeal New York Court Decision Rejecting Effort to Stop HFC Regs': 200 and the content b'{"MESSAGE":"","DUPLICATE":"Duplicate found","ARTICLEID":"6C39F4850C047B7B3F65A10C8664E225"}'
# c:\Users\203156\Desktop\Pipelines\Webscraping\venv\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'my.intelligence2day.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# 2026-02-24 17:19:53,980 | INFO | web_scraping_logger | API response status code for article 'BOCK CO2 Compressors Found to Vibrate Less at Ohio Supermarket': 200 and the content b'{"MESSAGE":"","DUPLICATE":"Duplicate found","ARTICLEID":"3CCA7F045B5238CC90B1553D3ACDB2D7"}'
# 2026-02-24 17:19:53,980 | INFO | web_scraping_logger | API response status code for article 'BOCK CO2 Compressors Found to Vibrate Less at Ohio Supermarket': 200 and the content b'{"MESSAGE":"","DUPLICATE":"Duplicate found","ARTICLEID":"3CCA7F045B5238CC90B1553D3ACDB2D7"}'
# c:\Users\203156\Desktop\Pipelines\Webscraping\venv\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'my.intelligence2day.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# 2026-02-24 17:19:54,198 | INFO | web_scraping_logger | API response status code for article 'Johnson Controls Introduces Air-to-Water Reversible York YAS R290 Heat Pump Models to the European Market': 200 and the content b'{"MESSAGE":"","DUPLICATE":"Duplicate found","ARTICLEID":"2F3DBB1623656B819D6B01B130EF15EF"}'
# 2026-02-24 17:19:54,198 | INFO | web_scraping_logger | API response status code for article 'Johnson Controls Introduces Air-to-Water Reversible York YAS R290 Heat Pump Models to the European Market': 200 and the content b'{"MESSAGE":"","DUPLICATE":"Duplicate found","ARTICLEID":"2F3DBB1623656B819D6B01B130EF15EF"}'
# c:\Users\203156\Desktop\Pipelines\Webscraping\venv\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'my.intelligence2day.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# 2026-02-24 17:19:54,419 | INFO | web_scraping_logger | API response status code for article 'HYTING Commissions ‘World’s First’ Customer-Installed Catalytic Hydrogen Air-Heating System': 200 and the content b'{"MESSAGE":"","DUPLICATE":"Duplicate found","ARTICLEID":"42199E4D37440B648A5158FCD50A178D"}'
# 2026-02-24 17:19:54,419 | INFO | web_scraping_logger | API response status code for article 'HYTING Commissions ‘World’s First’ Customer-Installed Catalytic Hydrogen Air-Heating System': 200 and the content b'{"MESSAGE":"","DUPLICATE":"Duplicate found","ARTICLEID":"42199E4D37440B648A5158FCD50A178D"}'
# c:\Users\203156\Desktop\Pipelines\Webscraping\venv\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'my.intelligence2day.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# 2026-02-24 17:19:54,629 | INFO | web_scraping_logger | API response status code for article 'Part 1: BAC’s Heat Rejection and Single-Phase Immersion Technology Provide ‘End-to-End’ Cooling Solution for Data Centers': 200 and the content b'{"MESSAGE":"","DUPLICATE":"Duplicate found","ARTICLEID":"A759BC93CEA5EDE99D2A9BDBBC5CC0A3"}'
# 2026-02-24 17:19:54,629 | INFO | web_scraping_logger | API response status code for article 'Part 1: BAC’s Heat Rejection and Single-Phase Immersion Technology Provide ‘End-to-End’ Cooling Solution for Data Centers': 200 and the content b'{"MESSAGE":"","DUPLICATE":"Duplicate found","ARTICLEID":"A759BC93CEA5EDE99D2A9BDBBC5CC0A3"}'
# c:\Users\203156\Desktop\Pipelines\Webscraping\venv\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'my.intelligence2day.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# 2026-02-24 17:19:54,871 | INFO | web_scraping_logger | API response status code for article 'Part 2: BAC’s Heat Rejection and Single-Phase Immersion Technology Provide ‘End-to-End’ Cooling Solution for Data Centers': 200 and the content b'{"MESSAGE":"","DUPLICATE":"Duplicate found","ARTICLEID":"839559685781421019AC9975A4E4C0EF"}'
# 2026-02-24 17:19:54,871 | INFO | web_scraping_logger | API response status code for article 'Part 2: BAC’s Heat Rejection and Single-Phase Immersion Technology Provide ‘End-to-End’ Cooling Solution for Data Centers': 200 and the content b'{"MESSAGE":"","DUPLICATE":"Duplicate found","ARTICLEID":"839559685781421019AC9975A4E4C0EF"}'
# c:\Users\203156\Desktop\Pipelines\Webscraping\venv\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'my.intelligence2day.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# 2026-02-24 17:19:55,179 | INFO | web_scraping_logger | API response status code for article 'Flow Environmental Services, St. Paul Local 455 Team Up for CO2 Heat-Pump Training and Demonstrations': 200 and the content b'{"MESSAGE":"","DUPLICATE":"Duplicate found","ARTICLEID":"604340338B4B607333ABC6AAB78D38F8"}'
# 2026-02-24 17:19:55,179 | INFO | web_scraping_logger | API response status code for article 'Flow Environmental Services, St. Paul Local 455 Team Up for CO2 Heat-Pump Training and Demonstrations': 200 and the content b'{"MESSAGE":"","DUPLICATE":"Duplicate found","ARTICLEID":"604340338B4B607333ABC6AAB78D38F8"}'
# c:\Users\203156\Desktop\Pipelines\Webscraping\venv\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'my.intelligence2day.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# 2026-02-24 17:19:55,421 | INFO | web_scraping_logger | API response status code for article 'Advansor Launches ‘Enhanced’ CuBig II With 50% More Cooling and Heating Capacity': 200 and the content b'{"MESSAGE":"","DUPLICATE":"Duplicate found","ARTICLEID":"E30E14914434362969D6C9BFAF5FBC74"}'
# 2026-02-24 17:19:55,421 | INFO | web_scraping_logger | API response status code for article 'Advansor Launches ‘Enhanced’ CuBig II With 50% More Cooling and Heating Capacity': 200 and the content b'{"MESSAGE":"","DUPLICATE":"Duplicate found","ARTICLEID":"E30E14914434362969D6C9BFAF5FBC74"}'
# c:\Users\203156\Desktop\Pipelines\Webscraping\venv\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'my.intelligence2day.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# 2026-02-24 17:19:55,687 | INFO | web_scraping_logger | API response status code for article 'Cencosud, Nestlé and OXXO Colombia to Present at ATMO LATAM 2026': 200 and the content b'{"MESSAGE":"","DUPLICATE":"Duplicate found","ARTICLEID":"0EEE559382A493C54C7876717A7CEE48"}'
# 2026-02-24 17:19:55,687 | INFO | web_scraping_logger | API response status code for article 'Cencosud, Nestlé and OXXO Colombia to Present at ATMO LATAM 2026': 200 and the content b'{"MESSAGE":"","DUPLICATE":"Duplicate found","ARTICLEID":"0EEE559382A493C54C7876717A7CEE48"}'
# c:\Users\203156\Desktop\Pipelines\Webscraping\venv\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'my.intelligence2day.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# 2026-02-24 17:19:55,912 | INFO | web_scraping_logger | API response status code for article 'California Grant of $1.5 Million to Fund Research on Risk of Propane in Outdoor Heat Pumps': 200 and the content b'{"MESSAGE":"","DUPLICATE":"Duplicate found","ARTICLEID":"6129F47E1D787D5CB4E88A5E7EDD5C40"}'
# 2026-02-24 17:19:55,912 | INFO | web_scraping_logger | API response status code for article 'California Grant of $1.5 Million to Fund Research on Risk of Propane in Outdoor Heat Pumps': 200 and the content b'{"MESSAGE":"","DUPLICATE":"Duplicate found","ARTICLEID":"6129F47E1D787D5CB4E88A5E7EDD5C40"}'
# c:\Users\203156\Desktop\Pipelines\Webscraping\venv\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'my.intelligence2day.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# 2026-02-24 17:19:56,132 | INFO | web_scraping_logger | API response status code for article 'Frascold’s New NEXUS Screw Compressor for High-Temperature Heat Pump Applications Can Work With Butane and Isopentane': 200 and the content b'{"MESSAGE":"","DUPLICATE":"Duplicate found","ARTICLEID":"AC3AB4DF27C747A91508A19C03F5EDA2"}'
# 2026-02-24 17:19:56,132 | INFO | web_scraping_logger | API response status code for article 'Frascold’s New NEXUS Screw Compressor for High-Temperature Heat Pump Applications Can Work With Butane and Isopentane': 200 and the content b'{"MESSAGE":"","DUPLICATE":"Duplicate found","ARTICLEID":"AC3AB4DF27C747A91508A19C03F5EDA2"}'
# c:\Users\203156\Desktop\Pipelines\Webscraping\venv\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'my.intelligence2day.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# 2026-02-24 17:19:56,371 | INFO | web_scraping_logger | API response status code for article 'EU Launches €1.8 Million Heat Pump Subscription Model for Leased Commercial and Public Buildings': 200 and the content b'{"MESSAGE":"","DUPLICATE":"Duplicate found","ARTICLEID":"1FF2F499C45441AD74333DEE54ABC297"}'
# 2026-02-24 17:19:56,371 | INFO | web_scraping_logger | API response status code for article 'EU Launches €1.8 Million Heat Pump Subscription Model for Leased Commercial and Public Buildings': 200 and the content b'{"MESSAGE":"","DUPLICATE":"Duplicate found","ARTICLEID":"1FF2F499C45441AD74333DEE54ABC297"}'
# c:\Users\203156\Desktop\Pipelines\Webscraping\venv\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'my.intelligence2day.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# 2026-02-24 17:19:56,643 | INFO | web_scraping_logger | API response status code for article 'HVAC&R Japan 2026: JEXSYS Launches 130°C High-Temperature Hot Water CO2 Heat Pump': 200 and the content b'{"MESSAGE":"","DUPLICATE":"Duplicate found","ARTICLEID":"F963172D413EEC2CD57C93BF880F1930"}'
# 2026-02-24 17:19:56,643 | INFO | web_scraping_logger | API response status code for article 'HVAC&R Japan 2026: JEXSYS Launches 130°C High-Temperature Hot Water CO2 Heat Pump': 200 and the content b'{"MESSAGE":"","DUPLICATE":"Duplicate found","ARTICLEID":"F963172D413EEC2CD57C93BF880F1930"}'
# c:\Users\203156\Desktop\Pipelines\Webscraping\venv\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'my.intelligence2day.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# 2026-02-24 17:19:56,903 | INFO | web_scraping_logger | API response status code for article 'Epta Completes Its Acquisition of Hauser': 200 and the content b'{"MESSAGE":"","DUPLICATE":"Duplicate found","ARTICLEID":"9EC6C6282653DD35ABECBDBDF7CF4249"}'
# 2026-02-24 17:19:56,903 | INFO | web_scraping_logger | API response status code for article 'Epta Completes Its Acquisition of Hauser': 200 and the content b'{"MESSAGE":"","DUPLICATE":"Duplicate found","ARTICLEID":"9EC6C6282653DD35ABECBDBDF7CF4249"}'
# c:\Users\203156\Desktop\Pipelines\Webscraping\venv\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'my.intelligence2day.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# 2026-02-24 17:19:57,134 | INFO | web_scraping_logger | API response status code for article 'Guide to Working with Propane Available in English': 200 and the content b'{"MESSAGE":"","DUPLICATE":"Duplicate found","ARTICLEID":"C56985C3D4492302B33EDB88A8ABE661"}'
# 2026-02-24 17:19:57,134 | INFO | web_scraping_logger | API response status code for article 'Guide to Working with Propane Available in English': 200 and the content b'{"MESSAGE":"","DUPLICATE":"Duplicate found","ARTICLEID":"C56985C3D4492302B33EDB88A8ABE661"}'
# c:\Users\203156\Desktop\Pipelines\Webscraping\venv\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'my.intelligence2day.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# 2026-02-24 17:19:57,386 | INFO | web_scraping_logger | API response status code for article 'Trane Technologies Completes Acquisition of Stellar Energy': 200 and the content b'{"MESSAGE":"","DUPLICATE":"Duplicate found","ARTICLEID":"8098815CAC3B16A12DA5E598EC105AEC"}'
# 2026-02-24 17:19:57,386 | INFO | web_scraping_logger | API response status code for article 'Trane Technologies Completes Acquisition of Stellar Energy': 200 and the content b'{"MESSAGE":"","DUPLICATE":"Duplicate found","ARTICLEID":"8098815CAC3B16A12DA5E598EC105AEC"}'
# c:\Users\203156\Desktop\Pipelines\Webscraping\venv\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'my.intelligence2day.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Program Files\Python312\Lib\logging\__init__.py", line 1163, in emit
#     stream.write(msg + self.terminator)
#   File "C:\Program Files\Python312\Lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeEncodeError: 'charmap' codec can't encode character '\u2011' in position 152: character maps to <undefined>
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\Users\203156\Desktop\Pipelines\Webscraping\venv\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\203156\Desktop\Pipelines\Webscraping\venv\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\203156\Desktop\Pipelines\Webscraping\venv\Lib\site-packages\ipykernel\kernelapp.py", line 758, in start
#     self.io_loop.start()
#   File "c:\Users\203156\Desktop\Pipelines\Webscraping\venv\Lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Program Files\Python312\Lib\asyncio\base_events.py", line 645, in run_forever
#     self._run_once()
#   File "C:\Program Files\Python312\Lib\asyncio\base_events.py", line 1999, in _run_once
#     handle._run()
#   File "C:\Program Files\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\203156\Desktop\Pipelines\Webscraping\venv\Lib\site-packages\ipykernel\kernelbase.py", line 614, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "c:\Users\203156\Desktop\Pipelines\Webscraping\venv\Lib\site-packages\ipykernel\kernelbase.py", line 471, in dispatch_shell
#     await result
#   File "c:\Users\203156\Desktop\Pipelines\Webscraping\venv\Lib\site-packages\ipykernel\ipkernel.py", line 366, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\203156\Desktop\Pipelines\Webscraping\venv\Lib\site-packages\ipykernel\kernelbase.py", line 827, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\203156\Desktop\Pipelines\Webscraping\venv\Lib\site-packages\ipykernel\ipkernel.py", line 458, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\203156\Desktop\Pipelines\Webscraping\venv\Lib\site-packages\ipykernel\zmqshell.py", line 663, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\203156\Desktop\Pipelines\Webscraping\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3123, in run_cell
#     result = self._run_cell(
#   File "c:\Users\203156\Desktop\Pipelines\Webscraping\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3178, in _run_cell
#     result = runner(coro)
#   File "c:\Users\203156\Desktop\Pipelines\Webscraping\venv\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\203156\Desktop\Pipelines\Webscraping\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3400, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\203156\Desktop\Pipelines\Webscraping\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3641, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\203156\Desktop\Pipelines\Webscraping\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3701, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\203156\AppData\Local\Temp\ipykernel_17008\2934185846.py", line 1, in <module>
#     api_push()
#   File "c:\Users\203156\Desktop\Pipelines\Webscraping\Scripts\API_push.py", line 46, in api_push
#     logger.info(f"API response status code for article '{row['title']}': {r.status_code} and the content {r.content}")
# Message: 'API response status code for article \'Trane Technologies to Acquire LiquidStack to Accelerate End‑to‑End Data Center Thermal Management Solutions\': 200 and the content b\'{"MESSAGE":"","DUPLICATE":"Duplicate found","ARTICLEID":"00EDEA030FE63BEAEDFC8C23A1C22407"}\''
# Arguments: ()
# 2026-02-24 17:19:57,630 | INFO | web_scraping_logger | API response status code for article 'Trane Technologies to Acquire LiquidStack to Accelerate End‑to‑End Data Center Thermal Management Solutions': 200 and the content b'{"MESSAGE":"","DUPLICATE":"Duplicate found","ARTICLEID":"00EDEA030FE63BEAEDFC8C23A1C22407"}'
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Program Files\Python312\Lib\logging\__init__.py", line 1163, in emit
#     stream.write(msg + self.terminator)
#   File "C:\Program Files\Python312\Lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeEncodeError: 'charmap' codec can't encode character '\u2011' in position 152: character maps to <undefined>
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\Users\203156\Desktop\Pipelines\Webscraping\venv\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\203156\Desktop\Pipelines\Webscraping\venv\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\203156\Desktop\Pipelines\Webscraping\venv\Lib\site-packages\ipykernel\kernelapp.py", line 758, in start
#     self.io_loop.start()
#   File "c:\Users\203156\Desktop\Pipelines\Webscraping\venv\Lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Program Files\Python312\Lib\asyncio\base_events.py", line 645, in run_forever
#     self._run_once()
#   File "C:\Program Files\Python312\Lib\asyncio\base_events.py", line 1999, in _run_once
#     handle._run()
#   File "C:\Program Files\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\203156\Desktop\Pipelines\Webscraping\venv\Lib\site-packages\ipykernel\kernelbase.py", line 614, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "c:\Users\203156\Desktop\Pipelines\Webscraping\venv\Lib\site-packages\ipykernel\kernelbase.py", line 471, in dispatch_shell
#     await result
#   File "c:\Users\203156\Desktop\Pipelines\Webscraping\venv\Lib\site-packages\ipykernel\ipkernel.py", line 366, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\203156\Desktop\Pipelines\Webscraping\venv\Lib\site-packages\ipykernel\kernelbase.py", line 827, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\203156\Desktop\Pipelines\Webscraping\venv\Lib\site-packages\ipykernel\ipkernel.py", line 458, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\203156\Desktop\Pipelines\Webscraping\venv\Lib\site-packages\ipykernel\zmqshell.py", line 663, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\203156\Desktop\Pipelines\Webscraping\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3123, in run_cell
#     result = self._run_cell(
#   File "c:\Users\203156\Desktop\Pipelines\Webscraping\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3178, in _run_cell
#     result = runner(coro)
#   File "c:\Users\203156\Desktop\Pipelines\Webscraping\venv\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\203156\Desktop\Pipelines\Webscraping\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3400, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\203156\Desktop\Pipelines\Webscraping\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3641, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\203156\Desktop\Pipelines\Webscraping\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3701, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\203156\AppData\Local\Temp\ipykernel_17008\2934185846.py", line 1, in <module>
#     api_push()
#   File "c:\Users\203156\Desktop\Pipelines\Webscraping\Scripts\API_push.py", line 46, in api_push
#     logger.info(f"API response status code for article '{row['title']}': {r.status_code} and the content {r.content}")
# Message: 'API response status code for article \'Trane Technologies to Acquire LiquidStack to Accelerate End‑to‑End Data Center Thermal Management Solutions\': 200 and the content b\'{"MESSAGE":"","DUPLICATE":"Duplicate found","ARTICLEID":"00EDEA030FE63BEAEDFC8C23A1C22407"}\''
# Arguments: ()
# 2026-02-24 17:19:57,630 | INFO | web_scraping_logger | API response status code for article 'Trane Technologies to Acquire LiquidStack to Accelerate End‑to‑End Data Center Thermal Management Solutions': 200 and the content b'{"MESSAGE":"","DUPLICATE":"Duplicate found","ARTICLEID":"00EDEA030FE63BEAEDFC8C23A1C22407"}'
# c:\Users\203156\Desktop\Pipelines\Webscraping\venv\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'my.intelligence2day.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# 2026-02-24 17:19:58,360 | INFO | web_scraping_logger | API response status code for article 'More from Trane Technologies': 200 and the content b'{"MESSAGE":"","DUPLICATE":"Duplicate found","ARTICLEID":"DAF71FDEB6AE07C06860F0042EA5EC0C"}'
# 2026-02-24 17:19:58,360 | INFO | web_scraping_logger | API response status code for article 'More from Trane Technologies': 200 and the content b'{"MESSAGE":"","DUPLICATE":"Duplicate found","ARTICLEID":"DAF71FDEB6AE07C06860F0042EA5EC0C"}'
# c:\Users\203156\Desktop\Pipelines\Webscraping\venv\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'my.intelligence2day.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# 2026-02-24 17:19:58,586 | INFO | web_scraping_logger | API response status code for article 'Trane Technologies to Present at the Barclays Industrial Select Conference': 200 and the content b'{"MESSAGE":"","DUPLICATE":"Duplicate found","ARTICLEID":"653263B5EF5C66B76DBD18EC890F7B8C"}'
# 2026-02-24 17:19:58,586 | INFO | web_scraping_logger | API response status code for article 'Trane Technologies to Present at the Barclays Industrial Select Conference': 200 and the content b'{"MESSAGE":"","DUPLICATE":"Duplicate found","ARTICLEID":"653263B5EF5C66B76DBD18EC890F7B8C"}'
# c:\Users\203156\Desktop\Pipelines\Webscraping\venv\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'my.intelligence2day.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# 2026-02-24 17:19:58,815 | INFO | web_scraping_logger | API response status code for article 'Trane Technologies to Present at the Citi Global Industrial Tech and Mobility Conference': 200 and the content b'{"MESSAGE":"","DUPLICATE":"Duplicate found","ARTICLEID":"4A07DB3255D26AD9D8F4A6F868A23B5C"}'
# 2026-02-24 17:19:58,815 | INFO | web_scraping_logger | API response status code for article 'Trane Technologies to Present at the Citi Global Industrial Tech and Mobility Conference': 200 and the content b'{"MESSAGE":"","DUPLICATE":"Duplicate found","ARTICLEID":"4A07DB3255D26AD9D8F4A6F868A23B5C"}'
# c:\Users\203156\Desktop\Pipelines\Webscraping\venv\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'my.intelligence2day.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# 2026-02-24 17:19:59,058 | INFO | web_scraping_logger | API response status code for article 'Trane Technologies Increases Dividend by 12%, Declares Quarterly Dividend': 200 and the content b'{"MESSAGE":"","DUPLICATE":"Duplicate found","ARTICLEID":"2C435ABF57982228DCA5624D80FE06DC"}'
# 2026-02-24 17:19:59,058 | INFO | web_scraping_logger | API response status code for article 'Trane Technologies Increases Dividend by 12%, Declares Quarterly Dividend': 200 and the content b'{"MESSAGE":"","DUPLICATE":"Duplicate found","ARTICLEID":"2C435ABF57982228DCA5624D80FE06DC"}'

# %%
logging.shutdown()

# %%
for handler in logger.handlers:
    handler.close()
